# %% [markdown]
# ## Algoritmos Genéticos
# Es una técnica inspirada en la evolución biológica que utiliza selección, cruzamiento y mutación para resolver problemas complejos y encontrar soluciones óptimas. <br>
# En este caso haré uso de un algoritmo genetico para determinar si un tablero de Sudoku de 3x3 generado cumple las condiciones de Sudoku

# %%
import random
import math

# Definir variables específicas para el Sudoku
numero_genes = 9  # La longitud del material genético de cada individuo (9 casillas del Sudoku)
tamano_poblacion = 100  # La cantidad de individuos en la población
precision = 30  # Cuántos individuos se seleccionan para reproducción (necesariamente mayor que 2)
probabilidad_mutacion = 0.4  # La probabilidad de que un individuo mute
valor_minimo_gen = 1
valor_maximo_gen = 3

# %% [markdown]
# <strong>crear_individuo(min, max):</strong> <br>Esta función crea un individuo aleatorio para ser utilizado en una población. Recibe como parámetros min y max, que representan los valores mínimos y máximos que los genes del individuo pueden tomar. La función utiliza una lista por comprensión para generar un cromosoma con números aleatorios dentro del rango especificado.
#
# <strong>crear_poblacion(numero_individuos):</strong> <br> Esta función crea una población nueva de individuos. Recibe como parámetro numero_individuos, que indica la cantidad de individuos que se crearán en la población. La función utiliza una lista por comprensión y llama a la función crear_individuo para generar cada individuo de la población.
#
# <strong>calcular_fitness(individuo):</strong> <br> Esta función calcula el fitness (aptitud) de un individuo del Sudoku. El fitness representa qué tan bueno es un individuo como solución del problema. En este caso, el fitness se calcula contando la cantidad de números repetidos en filas y columnas del Sudoku representado por el individuo. Utiliza un bucle for para recorrer las filas y columnas del Sudoku y la función set() para eliminar los elementos repetidos y obtener la cantidad de elementos únicos.
#
# <strong>FITNESS</strong> <br>
# Es una medida para evaluar el rendimiento de un individuo al problema dado <br>
# Mientras menor sea el valor del fitness, mejor

# %%
def crear_individuo(min, max):
    # Crea un individuo del Sudoku, representado como una lista de 9 números (1 a 3)
    return [random.randint(min, max) for i in range(numero_genes)]

def crear_poblacion(numero_individuos):
    # Crea una población nueva de individuos del Sudoku
    return [crear_individuo(valor_minimo_gen, valor_maximo_gen) for i in range(numero_individuos)]

def calcular_fitness(individuo):
    # Calcula el fitness de un individuo del Sudoku, contando la cantidad de números repetidos en filas y columnas
    fitness = 0
    for i in range(3):
        fila = individuo[i * 3 : (i + 1) * 3]
        # Desde la posicion 0 hasta la 9 de 3 en 3, empezando del 0
        columna = individuo[i : 9 : 3]
        # Determinar cuantos conjuntos unicos hay
        # Cada uno determina cuantos elementos únicos hay
        # En las filas y las columnas 
        # Cuando una fila o columna es única, se cuenta
        fitness += (3 - len(set(fila))) + (3 - len(set(columna)))
    return fitness

# %%
print(crear_poblacion(5))
# Out:
# [[1, 1, 1, 1, 1, 3, 1, 3, 1], [2, 2, 2, 1, 3, 3, 1, 1, 1], [1, 1, 3, 3, 3, 3, 3, 3, 1], [1, 1, 1, 2, 3, 3, 1, 3, 1], [1, 3, 2, 2, 3, 3, 3, 1, 2]]

# %%
print(calcular_fitness([2, 3, 3, 1, 3, 3, 2, 3, 2]))
# Out:
# 7

# %% [markdown]
# La función seleccion_y_reproduccion se encarga de realizar el proceso de selección y reproducción de una población de individuos en un algoritmo genético.
#
#
# <strong>poblacion_evaluada -> </strong> Se encarga de calcular el fitness de cada individuo de la variable de entrada poblacion <br>
# <br>
# <strong>poblacion_ordenada -> </strong> Se encarga de ordenar la poblacion en funcion del fitness
# <br>
# <strong>poblacion_seleccionada -> </strong> Selecciona los mejores individuos de la poblacion ordenada con presicion se refiere a cuantos individuos tomara, en este caso 30
# <br>
# <strong>Reproducción -> </strong> En este paso, se mezcla el material genético de los individuos seleccionados para crear nuevos individuos y llenar la población restante. Se utiliza un bucle for que itera desde precision hasta la longitud total de la población. En cada iteración, se elige un punto de cruce aleatorio y se seleccionan dos padres al azar de la población seleccionada. Luego, se realiza un cruce genético entre los padres, donde se mezcla su material genético en los nuevos individuos.
# <br>

# %%
def seleccion_y_reproduccion(poblacion):
    # Puntúa todos los individuos de la población y selecciona los mejores para reproducción
    poblacion_evaluada = [(indiv, calcular_fitness(indiv)) for indiv in poblacion]
    poblacion_ordenada = [indiv[0] for indiv in sorted(poblacion_evaluada, key=lambda x: x[1])]
    poblacion_seleccionada = poblacion_ordenada[precision:]
    
    # Se mezcla el material genético para crear nuevos individuos
    for i in range(precision, len(poblacion)):
        punto_cruce = random.randint(1, numero_genes - 1)  # Se elige un punto para hacer el intercambio
        padre = random.sample(poblacion_seleccionada, 2)  # Se eligen dos padres
        poblacion[i][:punto_cruce] = padre[0][:punto_cruce]  # Se mezcla el material genético de los padres en cada nuevo individuo
        poblacion[i][punto_cruce:] = padre[1][punto_cruce:]
    
    return poblacion

# %% [markdown]
# <strong>Mutacion -> </strong>  Se encarga e aplicar la mutacion a cada individuo de la poblacion

# %%
def mutacion(poblacion):
    # Se mutan los individuos al azar. Sin la mutación de nuevos genes nunca podría alcanzarse la solución.
    for i in range(precision, len(poblacion)):
        if random.random() <= probabilidad_mutacion:  # Cada individuo de la población (menos los padres) tiene una probabilidad de mutar
            punto = random.randint(0, numero_genes - 1)  # Se elige un punto al azar
            nuevo_valor = random.randint(valor_minimo_gen, valor_maximo_gen)  # y un nuevo valor para este punto
            
            # Es importante asegurarse de que el nuevo valor no sea igual al valor existente
            while nuevo_valor == poblacion[i][punto]:
                nuevo_valor = random.randint(valor_minimo_gen, valor_maximo_gen)
            
            # Se aplica la mutación
            poblacion[i][punto] = nuevo_valor
    
    return poblacion

# %% [markdown]
# ### Funcion para imprimir el tablero

# %%
# Función para imprimir el Sudoku en forma de tablero
def imprimir_sudoku(individuo):
    for i in range(3):
        if i % 3 == 0 and i != 0:
            print("- - -")
        for j in range(3):
            if j % 3 == 0 and j != 0:
                print("|", end=" ")
            print(individuo[i * 3 + j], end=" ")
        print()

# %% [markdown]
# <strong>Bucle For -> </strong>  Cada iteracion representa una generacion: <br>
# 1. Se crea una población inicial utilizando la función crear_poblacion, con un tamaño definido por tamano_poblacion. Esta población representa un conjunto de posibles soluciones al problema.
# <br>
# 2. Se evalúa el fitness de cada individuo de la población inicial mediante la función calcular_fitness, y se almacena en una lista llamada poblacion_evaluada. El fitness es una medida de qué tan bueno es cada individuo en términos de su capacidad para resolver el problema.
# <br>
# 3. La lista poblacion_evaluada se ordena en orden ascendente según el fitness de los individuos utilizando la función sorted y la clave de ordenamiento ordenar_por_segundo_elemento. Esto crea una lista llamada poblacion_ordenada en la cual los individuos con menor fitness aparecen primero.
# <br>
# 4. Se itera a través de la lista poblacion_ordenada y se imprime cada individuo junto con su fitness. Esto muestra la población inicial ordenada según su calidad.
# <br>
# 5. Se define el número de generaciones numero_generaciones que se utilizarán en la evolución de la población. También se inicializan variables para almacenar el mejor fitness encontrado, el número de generación actual y una bandera de salida (break_out_flag) para interrumpir el ciclo en caso de que se encuentre una solución óptima.
# <br>
# 6. Se inicia un bucle for que representa cada generación en la evolución de la población. En cada iteración, se realiza lo siguiente:
#
# a. Se calcula el fitness de todos los individuos en la población actual y se almacena en la lista puntuados.
#
# b. Se actualiza el número de generación numero_generacion.
#
# c. Se verifica si se ha encontrado una solución óptima, es decir, si se ha encontrado un individuo con fitness igual a cero. Si se encuentra una solución, se activa la bandera break_out_flag y se sale del bucle.
#
# d. Se aplica la selección y reproducción a la población utilizando la función seleccion_y_reproduccion.
#
# e. Se aplica la mutación a la población utilizando la función mutacion.
#
# f. Se evalúa el fitness de cada individuo en la población evolucionada y se ordena la lista poblacion_evaluada nuevamente en orden ascendente según el fitness. Esta es la nueva poblacion_ordenada.
#
# g. Se imprime el número de generación y los individuos de la poblacion_ordenada para mostrar el progreso de la evolución en cada generación.
#
# 7. Una vez finalizadas las generaciones, se imprime la población final ordenada según el fitness de los individuos.
# <br>
# 8. Se itera a través de la poblacion_ordenada y se imprime cada individuo junto con su fitness. Esto muestra la población final ordenada según su calidad.
# <br>
# 9. Se verifica si se encontró una solución óptima al verificar si el mejor_fitness es igual a cero. Si es cero, se imprime el individuo con mejor fitness y se muestra la solución a la ecuación específica que se está resolviendo. Además, se muestra en qué generación se encontró la solución. Si no se encuentra una solución óptima, se imprime un mensaje indicando que el algoritmo no pudo encontrar una solución.

# %%
# Inicializar una población
poblacion = crear_poblacion(tamano_poblacion)
print("Población Inicial:")
for individuo in poblacion:
    imprimir_sudoku(individuo)
    print()

numero_generaciones = 1000
mejor_fitness = math.inf
numero_generacion = 0
break_out_flag = False

# Se evoluciona la población
for i in range(numero_generaciones):
    puntuados = [(ind, calcular_fitness(ind)) for ind in poblacion] 
    numero_generacion += 1
    for indPun in puntuados:
        if indPun[1] < mejor_fitness:
            mejor_fitness = indPun[1]
        if indPun[1] == 0:
            break_out_flag = True
            break
    
    if break_out_flag:
        break
    
    poblacion = seleccion_y_reproduccion(poblacion)
    poblacion = mutacion(poblacion)
    
    poblacion_evaluada = [(ind, calcular_fitness(ind)) for ind in poblacion]
    poblacion_ordenada = [ind[0] for ind in sorted(poblacion_evaluada, key=lambda x: x[1])]
    
    print(f"Generación número: {numero_generacion}")
    imprimir_sudoku(poblacion_ordenada[0])
    print(f"Fitness: {calcular_fitness(poblacion_ordenada[0])}\n")

print("Población final:")
imprimir_sudoku(poblacion_ordenada[0])
print(f"Fitness: {calcular_fitness(poblacion_ordenada[0])}\n")

if mejor_fitness == 0:
    print("¡Se encontró una solución para el Sudoku!")
else:
    print("El algoritmo no pudo encontrar una solución para el Sudoku.")
# Out:
# Población Inicial:
# 1 3 2
# 3 2 2
# 3 1 3
#
# 1 3 1
# 1 1 2
# 2 3 3
#
# 2 2 2
# 1 3 1
# 3 1 2
#
# 1 3 3
# 1 3 3
# 3 1 1
#
# 2 1 2
# 1 2 1
# 1 2 3
#
# 1 3 3
# 2 3 3
# 2 1 2
#
# 2 2 1
# 2 1 1
# 1 1 1
#
# 3 2 2
# 3 1 2
# 3 1 1
#
# 3 2 3
# 3 3 3
# 1 1 1
#
# 2 3 3
# 1 2 1
# 3 3 3
#
# 3 2 2
# 2 3 1
# 2 1 3
#
# 1 1 3
# 2 1 1
# 2 2 2
#
# 3 1 3
# 1 3 1
# 2 3 2
#
# 3 1 2
# 2 2 3
# 1 3 1
#
# 3 1 2
# 1 1 1
# 1 3 2
#
# 2 2 1
# 3 2 1
# 3 1 2
#
# 2 2 1
# 3 3 2
# 1 3 1
#
# 1 2 1
# 3 2 2
# 3 1 3
#
# 1 3 3
# 1 1 1
# 1 2 2
#
# 2 3 3
# 1 3 1
# 2 3 2
#
# 2 1 3
# 1 1 2
# 1 2 2
#
# 3 3 2
# 1 1 1
# 3 1 1
#
# 1 2 3
# 3 1 2
# 1 2 3
#
# 1 2 3
# 2 3 2
# 3 1 3
#
# 1 1 2
# 2 1 1
# 1 3 1
#
# 3 3 1
# 3 3 2
# 2 3 2
#
# 1 1 1
# 2 1 2
# 2 2 2
#
# 1 2 2
# 2 2 1
# 1 2 2
#
# 3 3 3
# 1 2 3
# 3 2 2
#
# 3 2 3
# 3 1 3
# 3 2 2
#
# 2 3 2
# 3 2 3
# 1 3 1
#
# 1 2 3
# 3 1 3
# 3 3 1
#
# 3 2 1
# 1 2 3
# 3 2 1
#
# 2 3 3
# 3 3 2
# 3 1 2
#
# 1 2 2
# 1 1 1
# 3 3 1
#
# 2 2 2
# 2 1 1
# 1 3 2
#
# 1 2 1
# 3 1 2
# 3 3 1
#
# 2 3 3
# 2 3 2
# 3 2 1
#
# 3 2 1
# 1 3 2
# 1 2 1
#
# 2 1 3
# 2 1 1
# 3 2 1
#
# 3 1 2
# 1 2 3
# 2 2 1
#
# 2 1 2
# 2 3 3
# 1 2 3
#
# 2 3 1
# 1 2 2
# 2 1 2
#
# 1 3 2
# 1 3 2
# 1 3 2
#
# 1 1 1
# 2 2 2
# 2 1 3
#
# 3 1 2
# 2 2 1
# 1 2 2
#
# 1 2 3
# 2 2 2
# 1 1 1
#
# 2 3 3
# 2 1 3
# 3 3 2
#
# 2 2 1
# 3 3 3
# 3 1 3
#
# 1 2 1
# 2 1 1
# 1 1 1
#
# 2 1 1
# 3 3 1
# 2 2 2
#
# 1 2 3
# 3 3 3
# 2 1 2
#
# 3 3 2
# 1 2 3
# 1 2 3
#
# 2 1 1
# 1 2 1
# 1 2 3
#
# 1 1 2
# 3 3 1
# 2 2 3
#
# 1 3 2
# 2 2 2
# 3 2 3
#
# 2 2 3
# 2 2 2
# 2 1 3
#
# 2 2 1
# 2 3 3
# 3 3 3
#
# 2 1 1
# 1 2 3
# 3 3 2
#
# 3 2 3
# 3 1 2
# 3 1 3
#
# 3 2 3
# 1 2 3
# 1 2 3
#
# 1 3 1
# 2 3 3
# 2 2 3
#
# 2 1 1
# 3 3 1
# 1 2 2
#
# 3 3 2
# 3 3 1
# 2 2 3
#
# 3 3 2
# 2 1 1
# 2 2 3
#
# 3 3 1
# 3 1 2
# 1 2 1
#
# 1 1 2
# 1 3 3
# 2 3 3
#
# 2 1 3
# 3 2 2
# 3 2 1
#
# 2 3 1
# 2 1 1
# 2 3 3
#
# 1 2 2
# 3 3 3
# 2 1 2
#
# 2 3 2
# 1 3 1
# 2 3 3
#
# 2 1 3
# 1 3 3
# 1 2 1
#
# 2 2 3
# 2 3 2
# 1 1 2
#
# 2 2 2
# 2 3 1
# 3 2 1
#
# 3 1 2
# 3 2 3
# 1 2 3
#
# 1 2 1
# 1 2 1
# 3 2 2
#
# 2 1 3
# 3 3 1
# 3 3 1
#
# 1 1 1
# 1 3 3
# 3 2 1
#
# 1 2 2
# 1 1 3
# 1 1 3
#
# 2 1 3
# 2 1 2
# 2 1 2
#
# 1 3 3
# 1 3 2
# 1 1 3
#
# 2 2 3
# 1 2 3
# 2 3 3
#
# 3 1 2
# 1 1 3
# 3 2 3
#
# 2 3 2
# 3 3 1
# 1 2 2
#
# 3 2 3
# 3 2 3
# 2 3 3
#
# 2 2 1
# 1 2 1
# 3 2 1
#
# 3 3 2
# 3 3 3
# 3 2 1
#
# 1 3 1
# 3 2 1
# 1 2 1
#
# 3 3 2
# 2 3 1
# 1 3 2
#
# 2 3 3
# 2 2 3
# 2 2 1
#
# 3 3 3
# 1 1 2
# 2 2 2
#
# 1 3 2
# 2 2 1
# 3 3 3
#
# 1 3 1
# 1 2 1
# 3 2 1
#
# 1 1 3
# 3 3 1
# 2 1 3
#
# 1 2 3
# 3 2 3
# 2 1 1
#
# 1 2 1
# 3 3 3
# 3 2 3
#
# 1 2 1
# 3 1 2
# 1 3 1
#
# 2 1 2
# 1 3 3
# 2 2 1
#
# 3 1 3
# 2 2 3
# 1 1 1
#
# 3 1 1
# 2 2 2
# 1 1 1
#
# Generación número: 1
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 2
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 3
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 4
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 5
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 6
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 7
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 8
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 9
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 10
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 11
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 12
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 13
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 14
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 15
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 16
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 17
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 18
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 19
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 20
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 21
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 22
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 23
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 24
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 25
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 26
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 27
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 28
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 29
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 30
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 31
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 32
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 33
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 34
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 35
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 36
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 37
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 38
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 39
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 40
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 41
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 42
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 43
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 44
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 45
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 46
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 47
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 48
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 49
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 50
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 51
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 52
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 53
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 54
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 55
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 56
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 57
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 58
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 59
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 60
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 61
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 62
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 63
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 64
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 65
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 66
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 67
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 68
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 69
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 70
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 71
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 72
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 73
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 74
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 75
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 76
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 77
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 78
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 79
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 80
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 81
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 82
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 83
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 84
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 85
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 86
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 87
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 88
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 89
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 90
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 91
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 92
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 93
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 94
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 95
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 96
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 97
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 98
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 99
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 100
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 101
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 102
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 103
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 104
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 105
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 106
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 107
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 108
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 109
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 110
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 111
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 112
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 113
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 114
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 115
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 116
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 117
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 118
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 119
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 120
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 121
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 122
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 123
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 124
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 125
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 126
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 127
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 128
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 129
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 130
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 131
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 132
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 133
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 134
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 135
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 136
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 137
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 138
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 139
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 140
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 141
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 142
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 143
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 144
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 145
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 146
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 147
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 148
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 149
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 150
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 151
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 152
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 153
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 154
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 155
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 156
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 157
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 158
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 159
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 160
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 161
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 162
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 163
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 164
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 165
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 166
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 167
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 168
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 169
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 170
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 171
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 172
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 173
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 174
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 175
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 176
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 177
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 178
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 179
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 180
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 181
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 182
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 183
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 184
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 185
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 186
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 187
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 188
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 189
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 190
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 191
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 192
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 193
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 194
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 195
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 196
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 197
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 198
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 199
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 200
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 201
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 202
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 203
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 204
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 205
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 206
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 207
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 208
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 209
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 210
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 211
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 212
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 213
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 214
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 215
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 216
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 217
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 218
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 219
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 220
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 221
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 222
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 223
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 224
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 225
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 226
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 227
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 228
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 229
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 230
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 231
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 232
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 233
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 234
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 235
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 236
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 237
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 238
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 239
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 240
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 241
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 242
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 243
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 244
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 245
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 246
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 247
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 248
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 249
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 250
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 251
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 252
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 253
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 254
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 255
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 256
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 257
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 258
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 259
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 260
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 261
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 262
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 263
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 264
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 265
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 266
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 267
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 268
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 269
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 270
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 271
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 272
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 273
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 274
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 275
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 276
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 277
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 278
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 279
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 280
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 281
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 282
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 283
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 284
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 285
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 286
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 287
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 288
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 289
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 290
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 291
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 292
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 293
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 294
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 295
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 296
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 297
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 298
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 299
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 300
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 301
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 302
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 303
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 304
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 305
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 306
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 307
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 308
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 309
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 310
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 311
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 312
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 313
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 314
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 315
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 316
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 317
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 318
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 319
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 320
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 321
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 322
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 323
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 324
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 325
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 326
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 327
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 328
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 329
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 330
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 331
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 332
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 333
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 334
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 335
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 336
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 337
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 338
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 339
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 340
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 341
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 342
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 343
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 344
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 345
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 346
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 347
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 348
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 349
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 350
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 351
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 352
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 353
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 354
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 355
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 356
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 357
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 358
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 359
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 360
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 361
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 362
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 363
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 364
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 365
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 366
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 367
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 368
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 369
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 370
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 371
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 372
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 373
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 374
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 375
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 376
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 377
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 378
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 379
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 380
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 381
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 382
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 383
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 384
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 385
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 386
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 387
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 388
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 389
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 390
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 391
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 392
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 393
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 394
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 395
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 396
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 397
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 398
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 399
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 400
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 401
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 402
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 403
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 404
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 405
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 406
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 407
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 408
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 409
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 410
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 411
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 412
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 413
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 414
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 415
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 416
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 417
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 418
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 419
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 420
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 421
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 422
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 423
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 424
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 425
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 426
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 427
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 428
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 429
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 430
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 431
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 432
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 433
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 434
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 435
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 436
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 437
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 438
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 439
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 440
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 441
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 442
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 443
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 444
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 445
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 446
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 447
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 448
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 449
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 450
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 451
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 452
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 453
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 454
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 455
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 456
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 457
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 458
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 459
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 460
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 461
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 462
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 463
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 464
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 465
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 466
# 3 2 2
# 2 3 1
# 2 1 3
# Fitness: 2
#
# Generación número: 467
# 2 3 1
# 1 2 3
# 3 1 2
# Fitness: 0
#
# Población final:
# 2 3 1
# 1 2 3
# 3 1 2
# Fitness: 0
#
# ¡Se encontró una solución para el Sudoku!
